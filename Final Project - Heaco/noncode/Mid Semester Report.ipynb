# %% [markdown]
# # Project name, group member full names, group member UW emails
#
# Heaco
#
# Hao Kui Ma, hma99@wisc.edu
#
# Austin Michael Lee, alee88@wisc.edu
#
# Elliot Heath, eheath2@wisc.edu
#
# # Initial milestones copied from the last version you submitted, e.g., from the Wireframes
#
# **week 1-2**
#
# Users can create, read, update, and delete ‘tasks’
#
# Users can write titles and descriptions freely
#
# Users can mark a task as completed
#
# **week 3-4**
#
# Users can drag and drop tasks to reorder them in the UI
#
# Users can set frequency of the task (daily, weekly, etc)
#
# Authentication
#
# Data backend
#
# **week 5-6**
#
# Users can share those tasks with other users (view,edit,etc)
# Push notifications when the status of a task changes
# Users can view a history
#
# **week 7-8**
#
# Attaching pictures and/or files to a task
#
# Android ‘widgets’ to display and update tasks quickly
#
# Geolocation to indicate where a user was when they updated a task
#
# Siri/Alexa/Assistant voice commands
#
#
# # A revised set of milestones indicating:
#
# ## what all is completed by Nov 12
#
# Authentication
#
# Data backend
#
# ## weekly milestones with what you expect to finish on Nov 19, Nov 26, Dec 3, and Dec 10.
#
# **Nov 19**
#
# Users can create, read, update, and delete ‘tasks’
#
# Users can write titles and descriptions freely
#
# Users can mark a task as completed
#
# **Nov 26**
#
# Users can drag and drop tasks to reorder them in the UI
#
# Users can set frequency of the task (daily, weekly, etc)
#
# **Dec 3**
#
# Users can share those tasks with other users (view,edit,etc)
#
# Push notifications when the status of a task changes
#
# **Dec 10**
#
# Users can view a history
